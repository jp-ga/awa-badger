# %%
# create function to get data from h5 files
import numpy as np
import h5py
import os

# %%
def read_file(fname):
    with h5py.File(fname) as f:
        #data_x = np.array((
        #    f["images"].attrs["quad_pv_name"],
        #    f["images"].attrs["tdc_name"],
        #    f["images"].attrs["dipole_name"],
        #))
        images = f["images"][:]

    return 0, images

# %%
data_dir = "/home/awa/awa_data/12-05_6DReconstruction/YAG_centering"

# %%
test_img = read_file(os.path.join(data_dir, "DYG14_test.h5"))
# %matplotlib widget
from circle_detection import ScreenFinder
a = ScreenFinder(test_img[1][0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a.circle.center
# Out:
# (805.9074831868035, 567.2285839599652)

# %%
a.circle.radius*2
# Out:
# 1157.6227667974176

# %%
test_img = read_file(os.path.join(data_dir, "DYG15_test.h5"))
# %matplotlib widget
from circle_detection import ScreenFinder
b = ScreenFinder(test_img[1][0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
b.circle.center
# Out:
# (1071.2029826783375, 594.8697907882537)

# %%
b.circle.radius*2
# Out:
# 1298.1724994743395
