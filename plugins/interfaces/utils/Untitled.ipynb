# %%
from epics import caget
raw = caget("13ARV1:image1:ArrayData")

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.imshow(raw.reshape(1200, 1920)[500:700, 600:800])
plt.colorbar()

# %%
min(uint16(raw))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 min(uint16(raw))
#
# NameError: name 'uint16' is not defined

# %%
import ctypes
a=np.uint16(raw)
min(a)
max(a)
# Out:
# 65520

# %%
plt.imshow(a.reshape(1200, 1920)[500:700, 600:800])
plt.colorbar()

# %%
ok this can work
