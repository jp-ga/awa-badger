# %% [markdown]
# ## set up AWA environment and vocs

# %%
from plugins.environments.awa_environment import AWAEnvironment
from plugins.interfaces.awa_interface import AWAInterface

# import data from csv file
import pandas as pd
variable_file = "plugins/environments/awa_variables.csv"
observable_file = "plugins/environments/awa_observables.csv"

env = AWAEnvironment(variable_file, observable_file, interface=AWAInterface(), target_charge=1.0)

# %%
env.variables
# Out:
# {'AWA:Drive:DS1:Ctrl': [500.0, 550.0],
#  'AWA:Drive:DS3:Ctrl': [180.0, 260.0],
#  'AWA:Bira3Ctrl:Ch03': [-5.0, 5.0],
#  'AWA:Bira3Ctrl:Ch04': [-5.0, 5.0],
#  'AWA:Bira3Ctrl:Ch05': [-5.0, 5.0],
#  'AWA:Bira3Ctrl:Ch06': [-5.0, 5.0],
#  'AWALLRF:K1:SetPhase': [339.0, 359.0],
#  'AWA:DAC0:Ch08': [4.5, 5.9]}

# %%
from xopt import Xopt, Evaluator, VOCS
from xopt.generators.bayesian import BayesianExplorationGenerator, UpperConfidenceBoundGenerator
from xopt.generators.bayesian.models.standard import StandardModelConstructor
from xopt.generators.bayesian.turbo import SafetyTurboController, OptimizeTurboController

import time

def evaluate(inputs):
    env.set_variables(inputs)
    time.sleep(2.0)
    result = env.get_observables(["13ARV1:Sx"])
    result["total_rms_size"] = (result["13ARV1:Sx"]**2 + result["13ARV1:Sy"]**2)**0.5
    return result

# use only one variable
vocs = VOCS(variables=env.variables,
            objectives={"total_rms_size":"MINIMIZE"},
            constraints={
                "13ARV1:bb_penalty":["LESS_THAN",0.0],
                "13ARV1:log10_total_intensity":["GREATER_THAN", 4.5]
            })

# %% [markdown]
# ### get best point from old data

# %%
import yaml
import numpy as np
folder = "analysis/nn_prior/"
f_names = ["exploration_2_nd_filter.yml", "optimization_1.yml", "optimization_2.yml"]
dfs = []
for name in f_names:
    with open(folder + name, "r") as file:
        f = yaml.safe_load(file)
        dfs += [pd.DataFrame(f["data"])]

data = pd.concat(dfs, ignore_index=True)
data = data.dropna(subset=["total_rms_size"])
data["total_rms_size"] = data["total_rms_size"]

old_vocs = VOCS(**f["vocs"])

sorted_idx = np.argsort(data["total_rms_size"].to_numpy())
print(data["total_rms_size"].iloc[sorted_idx])
old_samples = data[vocs.variable_names].iloc[sorted_idx[:30]]


# account for phase drift 103 deg
old_samples["AWALLRF:K1:SetPhase"] = old_samples["AWALLRF:K1:SetPhase"] + 103
old_samples
# Out:
# 48      15.790469
# 96      16.269969
# 283     18.454183
# 282     19.338272
# 284     20.040956
#           ...
# 174    100.480297
# 297    104.210789
# 73     105.367202
# 111    105.464284
# 211    110.238814
# Name: total_rms_size, Length: 253, dtype: float64
#      AWA:Bira3Ctrl:Ch03  AWA:Bira3Ctrl:Ch04  AWA:Bira3Ctrl:Ch05
# 48            -0.806105           -0.776121            1.705201  \
# 96            -1.911520            0.936251            0.374213
# 283            0.613589           -0.266364            0.856463
# 282            0.590067           -0.293451            0.835026
# 284            0.636957           -0.293168            0.877690
# 329           -0.968191            0.450441           -0.717785
# 280            0.566323           -0.321093            0.813333
# 328           -0.974335            0.446432           -0.718588
# 322           -0.967682            0.456036           -0.708589
# 326           -0.956383            0.448485           -0.714376
# 317           -0.957189            0.458733           -0.701257
# 327           -0.959503            0.454402           -0.710323
# 318           -0.957807            0.471772           -0.714207
# 313           -0.959072            0.505814           -0.736603
# 302           -0.961535            0.511659           -0.690263
# 309           -0.956314            0.479975           -0.677565
# 325           -0.973242            0.466387           -0.715070
# 324           -0.977150            0.447983           -0.707368
# 315           -0.961052            0.450681           -0.758253
# 278            0.542165           -0.293218            0.791046
# 311           -0.957079            0.476772           -0.680376
# 334           -0.967679            0.496652           -0.763661
# 310           -0.958135            0.511039           -0.693989
# 320           -0.939794            0.462127           -0.705140
# 63             1.817412           -2.238171           -0.224582
# 316           -0.954725            0.451727           -0.786078
# 307           -0.963818            0.515737           -0.664801
# 281            0.542294           -0.349102            0.791305
# 301           -0.959578            0.512259           -0.739149
# 53             0.557646           -1.378730           -0.633100
#
#      AWA:Bira3Ctrl:Ch06  AWA:DAC0:Ch08  AWA:Drive:DS1:Ctrl
# 48             0.131568       4.929338          502.170090  \
# 96             1.045129       4.887869          533.021678
# 283           -1.384460       5.536879          549.273413
# 282           -1.357757       5.582421          548.718040
# 284           -1.357982       5.490883          549.830475
# 329            1.360013       5.852420          549.513989
# 280           -1.384709       5.627106          549.268680
# 328            1.352640       5.858104          549.322819
# 322            1.362970       5.861005          549.644325
# 326            1.355010       5.845547          549.617731
# 317            1.365902       5.857091          549.716634
# 327            1.367522       5.842346          549.550907
# 318            1.358741       5.867873          549.306492
# 313            1.368659       5.846853          549.346441
# 302            1.311698       5.845804          549.421767
# 309            1.295057       5.851967          549.667387
# 325            1.357424       5.878330          549.773915
# 324            1.348739       5.863597          549.901578
# 315            1.358901       5.836887          549.123199
# 278           -1.412478       5.582475          549.814574
# 311            1.351772       5.846736          549.184880
# 334            1.330727       5.838481          549.282304
# 310            1.331888       5.846199          549.477058
# 320            1.360912       5.869160          549.968845
# 63             0.737849       5.150253          516.601878
# 316            1.364903       5.850147          549.331821
# 307            1.304711       5.852011          549.393761
# 281           -1.412082       5.670985          549.819710
# 301            1.274763       5.850841          549.720434
# 53             1.280353       5.163607          517.460885
#
#      AWA:Drive:DS3:Ctrl  AWALLRF:K1:SetPhase
# 48           208.105682           353.911686
# 96           242.381544           344.579240
# 283          217.433380           345.626308
# 282          214.806440           346.267728
# 284          214.776356           344.977770
# 329          197.374867           346.445403
# 280          212.212888           346.902449
# 328          196.463718           346.367527
# 322          195.530981           346.555834
# 326          195.117060           346.508086
# 317          195.626744           346.739950
# 327          195.006040           346.835271
# 318          195.774433           346.702459
# 313          195.475244           346.839588
# 302          195.412733           346.725377
# 309          195.487736           346.800538
# 325          194.553297           346.282521
# 324          194.729020           346.629243
# 315          195.600640           346.872898
# 278          209.724226           347.517516
# 311          195.511121           346.656543
# 334          195.219537           346.713745
# 310          195.511313           346.719663
# 320          195.146146           346.886907
# 63           257.512703           341.435271
# 316          195.564557           346.687936
# 307          195.513429           346.842825
# 281          214.748311           346.277681
# 301          195.383719           346.746487
# 53           217.086574           352.835920

# %% [markdown]
# ### import nn prior model

# %% [markdown]
# ### Create Xopt object

# %%
model_constructor = StandardModelConstructor(
    use_low_noise_prior=False,
    #mean_modules={"total_rms_size":awa_model}
)
generator = UpperConfidenceBoundGenerator(
    vocs=vocs, 
    model_constructor=model_constructor,
    turbo_controller=OptimizeTurboController(vocs=vocs, length=0.1)
)
generator.numerical_optimizer.n_raw_samples = 512
generator.numerical_optimizer.n_restarts = 512

evaluator = Evaluator(function=evaluate)
X = Xopt(vocs=vocs, evaluator=evaluator, generator=generator)
X.options.dump_file = "run_data_2023_06_19/resampling.yml"

# %%
X
# Out:
#             Xopt
# ________________________________
# Version: 1.4.1+50.ge9fc8ac.dirty
# Data size: 0
# Config as YAML:
# xopt: {asynch: false, strict: false, dump_file: run_data_2023_06_19/resampling.yml,
#   max_evaluations: null}
# generator:
#   name: upper_confidence_bound
#   model: null
#   turbo_controller:
#     dim: 8
#     batch_size: 1
#     length: 0.1
#     length_min: 0.0078125
#     length_max: 2.0
#     failure_counter: 0
#     failure_tolerance: 4
#     success_counter: 0
#     success_tolerance: 4
#     center_x: null
#     scale_factor: 2.0
#     tkwargs: {dtype: torch.float64}
#     minimize: true
#     best_value: null
#   use_cuda: false
#   model_constructor:
#     name: standard
#     use_low_noise_prior: false
#     covar_modules: {}
#     mean_modules: {}
#     trainable_mean_keys: []
#     dtype: torch.float64
#     device: cpu
#   numerical_optimizer: {name: LBFGS, n_raw_samples: 512, n_restarts: 512, max_iter: 2000}
#   max_travel_distances: null
#   n_monte_carlo_samples: 128
#   beta: 2.0
# evaluator:
#   function: __main__.evaluate
#   max_workers: 1
#   function_kwargs: {}
#   vectorized: false
# vocs:
#   variables:
#     AWA:Drive:DS1:Ctrl: [500.0, 550.0]
#     AWA:Drive:DS3:Ctrl: [180.0, 260.0]
#     AWA:Bira3Ctrl:Ch03: [-5.0, 5.0]
#     AWA:Bira3Ctrl:Ch04: [-5.0, 5.0]
#     AWA:Bira3Ctrl:Ch05: [-5.0, 5.0]
#     AWA:Bira3Ctrl:Ch06: [-5.0, 5.0]
#     AWALLRF:K1:SetPhase: [339.0, 359.0]
#     AWA:DAC0:Ch08: [4.5, 5.9]
#   constraints:
#     13ARV1:bb_penalty: [LESS_THAN, 0.0]
#     13ARV1:log10_total_intensity: [GREATER_THAN, 4.5]
#   objectives: {total_rms_size: MINIMIZE}
#   constants: {}

# %% [markdown]
# ### Initialize w/ fixed initial points

# %%
# evaluate that point in xopt
X.evaluate_data(old_samples)
# Out:
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Mon Jun 19 2023 13:56:40.399722644
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Mon Jun 19 2023 13:56:40.399913897
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Mon Jun 19 2023 13:56:40.400063431
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Mon Jun 19 2023 13:56:40.400194385
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Mon Jun 19 2023 13:56:40.400315530
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Mon Jun 19 2023 13:56:40.400433386
# ..................................................................
#     AWA:Bira3Ctrl:Ch03  AWA:Bira3Ctrl:Ch04  AWA:Bira3Ctrl:Ch05
# 1            -0.806105           -0.776121            1.705201  \
# 2            -1.911520            0.936251            0.374213
# 3             0.613589           -0.266364            0.856463
# 4             0.590067           -0.293451            0.835026
# 5             0.636957           -0.293168            0.877690
# 6            -0.968191            0.450441           -0.717785
# 7             0.566323           -0.321093            0.813333
# 8            -0.974335            0.446432           -0.718588
# 9            -0.967682            0.456036           -0.708589
# 10           -0.956383            0.448485           -0.714376
# 11           -0.957189            0.458733           -0.701257
# 12           -0.959503            0.454402           -0.710323
# 13           -0.957807            0.471772           -0.714207
# 14           -0.959072            0.505814           -0.736603
# 15           -0.961535            0.511659           -0.690263
# 16           -0.956314            0.479975           -0.677565
# 17           -0.973242            0.466387           -0.715070
# 18           -0.977150            0.447983           -0.707368
# 19           -0.961052            0.450681           -0.758253
# 20            0.542165           -0.293218            0.791046
# 21           -0.957079            0.476772           -0.680376
# 22           -0.967679            0.496652           -0.763661
# 23           -0.958135            0.511039           -0.693989
# 24           -0.939794            0.462127           -0.705140
# 25            1.817412           -2.238171           -0.224582
# 26           -0.954725            0.451727           -0.786078
# 27           -0.963818            0.515737           -0.664801
# 28            0.542294           -0.349102            0.791305
# 29           -0.959578            0.512259           -0.739149
# 30            0.557646           -1.378730           -0.633100
#
#     AWA:Bira3Ctrl:Ch06  AWA:DAC0:Ch08  AWA:Drive:DS1:Ctrl  AWA:Drive:DS3:Ctrl
# 1             0.131568       4.929338          502.170090          208.105682  \
# 2             1.045129       4.887869          533.021678          242.381544
# 3            -1.384460       5.536879          549.273413          217.433380
# 4            -1.357757       5.582421          548.718040          214.806440
# 5            -1.357982       5.490883          549.830475          214.776356
# 6             1.360013       5.852420          549.513989          197.374867
# 7            -1.384709       5.627106          549.268680          212.212888
# 8             1.352640       5.858104          549.322819          196.463718
# 9             1.362970       5.861005          549.644325          195.530981
# 10            1.355010       5.845547          549.617731          195.117060
# 11            1.365902       5.857091          549.716634          195.626744
# 12            1.367522       5.842346          549.550907          195.006040
# 13            1.358741       5.867873          549.306492          195.774433
# 14            1.368659       5.846853          549.346441          195.475244
# 15            1.311698       5.845804          549.421767          195.412733
# 16            1.295057       5.851967          549.667387          195.487736
# 17            1.357424       5.878330          549.773915          194.553297
# 18            1.348739       5.863597          549.901578          194.729020
# 19            1.358901       5.836887          549.123199          195.600640
# 20           -1.412478       5.582475          549.814574          209.724226
# 21            1.351772       5.846736          549.184880          195.511121
# 22            1.330727       5.838481          549.282304          195.219537
# 23            1.331888       5.846199          549.477058          195.511313
# 24            1.360912       5.869160          549.968845          195.146146
# 25            0.737849       5.150253          516.601878          257.512703
# 26            1.364903       5.850147          549.331821          195.564557
# 27            1.304711       5.852011          549.393761          195.513429
# 28           -1.412082       5.670985          549.819710          214.748311
# 29            1.274763       5.850841          549.720434          195.383719
# 30            1.280353       5.163607          517.460885          217.086574
#
#     AWALLRF:K1:SetPhase  13ARV1:image1:ArraySize1_RBV
# 1            353.911686                        1200.0  \
# 2            344.579240                        1200.0
# 3            345.626308                        1200.0
# 4            346.267728                        1200.0
# 5            344.977770                        1200.0
# 6            346.445403                        1200.0
# 7            346.902449                        1200.0
# 8            346.367527                        1200.0
# 9            346.555834                        1200.0
# 10           346.508086                        1200.0
# 11           346.739950                        1200.0
# 12           346.835271                        1200.0
# 13           346.702459                        1200.0
# 14           346.839588                        1200.0
# 15           346.725377                        1200.0
# 16           346.800538                        1200.0
# 17           346.282521                        1200.0
# 18           346.629243                        1200.0
# 19           346.872898                        1200.0
# 20           347.517516                        1200.0
# 21           346.656543                        1200.0
# 22           346.713745                        1200.0
# 23           346.719663                        1200.0
# 24           346.886907                        1200.0
# 25           341.435271                        1200.0
# 26           346.687936                        1200.0
# 27           346.842825                        1200.0
# 28           346.277681                        1200.0
# 29           346.746487                        1200.0
# 30           352.835920                        1200.0
#
#     13ARV1:image1:ArraySize0_RBV  ...  13ARV1:Cx_std  13ARV1:Cy_std
# 1                         1920.0  ...       0.829994       0.229461  \
# 2                         1920.0  ...       0.405735       0.651988
# 3                         1920.0  ...       0.716650       1.454609
# 4                         1920.0  ...       0.560937       0.701598
# 5                         1920.0  ...       0.672733       0.613940
# 6                         1920.0  ...       0.846478       0.340146
# 7                         1920.0  ...       0.369383       1.067088
# 8                         1920.0  ...       0.535709       0.577093
# 9                         1920.0  ...       0.508046       0.959473
# 10                        1920.0  ...       0.609895       0.210581
# 11                        1920.0  ...       0.624112       0.246613
# 12                        1920.0  ...       0.730535       0.641381
# 13                        1920.0  ...       1.085509       0.437037
# 14                        1920.0  ...       0.689763       0.779074
# 15                        1920.0  ...       0.497349       0.381918
# 16                        1920.0  ...       0.393878       0.211491
# 17                        1920.0  ...       0.745443       0.624499
# 18                        1920.0  ...       0.583714       0.741557
# 19                        1920.0  ...       0.761482       0.720832
# 20                        1920.0  ...       0.445094       0.957636
# 21                        1920.0  ...       0.518203       0.429371
# 22                        1920.0  ...       0.312875       0.632878
# 23                        1920.0  ...       0.732162       0.573672
# 24                        1920.0  ...       0.608472       0.477575
# 25                        1920.0  ...       0.460383       0.327673
# 26                        1920.0  ...       0.575581       0.511339
# 27                        1920.0  ...       0.574696       0.778795
# 28                        1920.0  ...       0.105769       0.939353
# 29                        1920.0  ...       0.476334       0.478347
# 30                        1920.0  ...       0.213985       1.653925
#
#     13ARV1:Sx_std  13ARV1:Sy_std  13ARV1:bb_penalty_std
# 1        0.171975       0.601814               1.213546  \
# 2        0.250429       0.256740               0.902208
# 3        0.636275       0.610496               1.572938
# 4        0.550487       0.266404               0.924189
# 5        0.243470       0.148704               1.000017
# 6        0.050326       0.103044               0.550990
# 7        0.139763       0.125555               1.098699
# 8        0.128232       0.223792               0.478481
# 9        0.261136       0.170791               1.076855
# 10       0.176595       0.137273               0.753773
# 11       0.087440       0.080578               0.464578
# 12       0.237519       0.169419               0.481577
# 13       0.059513       0.180210               0.780218
# 14       0.139906       0.118069               0.855896
# 15       0.222130       0.119975               0.624740
# 16       0.172089       0.146942               0.597409
# 17       0.139951       0.166293               0.948041
# 18       0.131140       0.211855               0.571932
# 19       0.044941       0.318969               0.644022
# 20       0.081480       0.535593               0.805720
# 21       0.415239       0.175161               0.935256
# 22       0.065152       0.218611               0.555811
# 23       0.127702       0.215253               0.746652
# 24       0.119719       0.138671               0.636977
# 25       0.327040       0.078444               0.443353
# 26       0.049949       0.450166               0.810944
# 27       0.158148       0.201287               0.773207
# 28       0.035175       0.143516               0.715598
# 29       0.074896       0.480996               0.522403
# 30       1.189178       0.841082               3.156484
#
#     13ARV1:total_intensity_std  13ARV1:log10_total_intensity_std
# 1                417114.485839                          0.084282  \
# 2                185657.501940                          0.040598
# 3                479575.896665                          0.096419
# 4                436647.098985                          0.076473
# 5                145498.336196                          0.028552
# 6                272678.665105                          0.045972
# 7                252015.105055                          0.052455
# 8                304219.675827                          0.050608
# 9                463003.159640                          0.080247
# 10               270718.399506                          0.044968
# 11                38899.804595                          0.006567
# 12               343729.895507                          0.059317
# 13               193310.288970                          0.032771
# 14               250585.322563                          0.044802
# 15               339659.049914                          0.067045
# 16               239891.140552                          0.044635
# 17               178489.847204                          0.030329
# 18               307684.022389                          0.049932
# 19               141864.094451                          0.025516
# 20               372062.385543                          0.066022
# 21               301959.303553                          0.047863
# 22               109936.102554                          0.019730
# 23               281278.399201                          0.049421
# 24               142303.128517                          0.024163
# 25               189552.709699                          0.038586
# 26               377945.937238                          0.072874
# 27               223376.323267                          0.041058
# 28               139650.823071                          0.028402
# 29               301350.101537                          0.062329
# 30               388159.904120                          0.073115
#
#     total_rms_size  xopt_runtime  xopt_error
# 1        15.821181      9.251255       False
# 2        15.600330     11.015657       False
# 3        21.120533      9.699843       False
# 4        21.366142     12.495802       False
# 5        23.221382      7.770248       False
# 6        23.597209      9.234790       False
# 7        22.089075      7.982702       False
# 8        24.197822      7.504057       False
# 9        24.407877      7.034743       False
# 10       24.482337      7.220196       False
# 11       24.578025      6.286747       False
# 12       24.631594      6.447165       False
# 13       24.889271      8.008152       False
# 14       25.480820      6.986542       False
# 15       25.365301      6.834347       False
# 16       25.004750      6.717962       False
# 17       24.818062      7.434536       False
# 18       24.986429      5.892197       False
# 19       24.885550      8.869420       False
# 20       23.544539     11.712576       False
# 21       25.980224      5.891860       False
# 22       25.280765      7.111135       False
# 23       26.441676      6.492353       False
# 24       25.674021     11.979916       False
# 25       21.966412     12.787573       False
# 26       25.247550      8.493112       False
# 27       26.877705      6.495474       False
# 28       24.783766      7.494676       False
# 29       26.037324      9.218237       False
# 30       23.235017      7.501775       False
#
# [30 rows x 31 columns]

# %% [markdown]
# ### Run optimization

# %%
X.data
# Out:
#     AWA:Bira3Ctrl:Ch03  AWA:Bira3Ctrl:Ch04  AWA:Bira3Ctrl:Ch05
# 1            -0.806105           -0.776121            1.705201  \
# 2            -1.911520            0.936251            0.374213
# 3             0.613589           -0.266364            0.856463
# 4             0.590067           -0.293451            0.835026
# 5             0.636957           -0.293168            0.877690
# 6            -0.968191            0.450441           -0.717785
# 7             0.566323           -0.321093            0.813333
# 8            -0.974335            0.446432           -0.718588
# 9            -0.967682            0.456036           -0.708589
# 10           -0.956383            0.448485           -0.714376
# 11           -0.957189            0.458733           -0.701257
# 12           -0.959503            0.454402           -0.710323
# 13           -0.957807            0.471772           -0.714207
# 14           -0.959072            0.505814           -0.736603
# 15           -0.961535            0.511659           -0.690263
# 16           -0.956314            0.479975           -0.677565
# 17           -0.973242            0.466387           -0.715070
# 18           -0.977150            0.447983           -0.707368
# 19           -0.961052            0.450681           -0.758253
# 20            0.542165           -0.293218            0.791046
# 21           -0.957079            0.476772           -0.680376
# 22           -0.967679            0.496652           -0.763661
# 23           -0.958135            0.511039           -0.693989
# 24           -0.939794            0.462127           -0.705140
# 25            1.817412           -2.238171           -0.224582
# 26           -0.954725            0.451727           -0.786078
# 27           -0.963818            0.515737           -0.664801
# 28            0.542294           -0.349102            0.791305
# 29           -0.959578            0.512259           -0.739149
# 30            0.557646           -1.378730           -0.633100
#
#     AWA:Bira3Ctrl:Ch06  AWA:DAC0:Ch08  AWA:Drive:DS1:Ctrl  AWA:Drive:DS3:Ctrl
# 1             0.131568       4.929338          502.170090          208.105682  \
# 2             1.045129       4.887869          533.021678          242.381544
# 3            -1.384460       5.536879          549.273413          217.433380
# 4            -1.357757       5.582421          548.718040          214.806440
# 5            -1.357982       5.490883          549.830475          214.776356
# 6             1.360013       5.852420          549.513989          197.374867
# 7            -1.384709       5.627106          549.268680          212.212888
# 8             1.352640       5.858104          549.322819          196.463718
# 9             1.362970       5.861005          549.644325          195.530981
# 10            1.355010       5.845547          549.617731          195.117060
# 11            1.365902       5.857091          549.716634          195.626744
# 12            1.367522       5.842346          549.550907          195.006040
# 13            1.358741       5.867873          549.306492          195.774433
# 14            1.368659       5.846853          549.346441          195.475244
# 15            1.311698       5.845804          549.421767          195.412733
# 16            1.295057       5.851967          549.667387          195.487736
# 17            1.357424       5.878330          549.773915          194.553297
# 18            1.348739       5.863597          549.901578          194.729020
# 19            1.358901       5.836887          549.123199          195.600640
# 20           -1.412478       5.582475          549.814574          209.724226
# 21            1.351772       5.846736          549.184880          195.511121
# 22            1.330727       5.838481          549.282304          195.219537
# 23            1.331888       5.846199          549.477058          195.511313
# 24            1.360912       5.869160          549.968845          195.146146
# 25            0.737849       5.150253          516.601878          257.512703
# 26            1.364903       5.850147          549.331821          195.564557
# 27            1.304711       5.852011          549.393761          195.513429
# 28           -1.412082       5.670985          549.819710          214.748311
# 29            1.274763       5.850841          549.720434          195.383719
# 30            1.280353       5.163607          517.460885          217.086574
#
#     AWALLRF:K1:SetPhase  13ARV1:image1:ArraySize1_RBV
# 1            353.911686                        1200.0  \
# 2            344.579240                        1200.0
# 3            345.626308                        1200.0
# 4            346.267728                        1200.0
# 5            344.977770                        1200.0
# 6            346.445403                        1200.0
# 7            346.902449                        1200.0
# 8            346.367527                        1200.0
# 9            346.555834                        1200.0
# 10           346.508086                        1200.0
# 11           346.739950                        1200.0
# 12           346.835271                        1200.0
# 13           346.702459                        1200.0
# 14           346.839588                        1200.0
# 15           346.725377                        1200.0
# 16           346.800538                        1200.0
# 17           346.282521                        1200.0
# 18           346.629243                        1200.0
# 19           346.872898                        1200.0
# 20           347.517516                        1200.0
# 21           346.656543                        1200.0
# 22           346.713745                        1200.0
# 23           346.719663                        1200.0
# 24           346.886907                        1200.0
# 25           341.435271                        1200.0
# 26           346.687936                        1200.0
# 27           346.842825                        1200.0
# 28           346.277681                        1200.0
# 29           346.746487                        1200.0
# 30           352.835920                        1200.0
#
#     13ARV1:image1:ArraySize0_RBV  ...  13ARV1:Cx_std  13ARV1:Cy_std
# 1                         1920.0  ...       0.829994       0.229461  \
# 2                         1920.0  ...       0.405735       0.651988
# 3                         1920.0  ...       0.716650       1.454609
# 4                         1920.0  ...       0.560937       0.701598
# 5                         1920.0  ...       0.672733       0.613940
# 6                         1920.0  ...       0.846478       0.340146
# 7                         1920.0  ...       0.369383       1.067088
# 8                         1920.0  ...       0.535709       0.577093
# 9                         1920.0  ...       0.508046       0.959473
# 10                        1920.0  ...       0.609895       0.210581
# 11                        1920.0  ...       0.624112       0.246613
# 12                        1920.0  ...       0.730535       0.641381
# 13                        1920.0  ...       1.085509       0.437037
# 14                        1920.0  ...       0.689763       0.779074
# 15                        1920.0  ...       0.497349       0.381918
# 16                        1920.0  ...       0.393878       0.211491
# 17                        1920.0  ...       0.745443       0.624499
# 18                        1920.0  ...       0.583714       0.741557
# 19                        1920.0  ...       0.761482       0.720832
# 20                        1920.0  ...       0.445094       0.957636
# 21                        1920.0  ...       0.518203       0.429371
# 22                        1920.0  ...       0.312875       0.632878
# 23                        1920.0  ...       0.732162       0.573672
# 24                        1920.0  ...       0.608472       0.477575
# 25                        1920.0  ...       0.460383       0.327673
# 26                        1920.0  ...       0.575581       0.511339
# 27                        1920.0  ...       0.574696       0.778795
# 28                        1920.0  ...       0.105769       0.939353
# 29                        1920.0  ...       0.476334       0.478347
# 30                        1920.0  ...       0.213985       1.653925
#
#     13ARV1:Sx_std  13ARV1:Sy_std  13ARV1:bb_penalty_std
# 1        0.171975       0.601814               1.213546  \
# 2        0.250429       0.256740               0.902208
# 3        0.636275       0.610496               1.572938
# 4        0.550487       0.266404               0.924189
# 5        0.243470       0.148704               1.000017
# 6        0.050326       0.103044               0.550990
# 7        0.139763       0.125555               1.098699
# 8        0.128232       0.223792               0.478481
# 9        0.261136       0.170791               1.076855
# 10       0.176595       0.137273               0.753773
# 11       0.087440       0.080578               0.464578
# 12       0.237519       0.169419               0.481577
# 13       0.059513       0.180210               0.780218
# 14       0.139906       0.118069               0.855896
# 15       0.222130       0.119975               0.624740
# 16       0.172089       0.146942               0.597409
# 17       0.139951       0.166293               0.948041
# 18       0.131140       0.211855               0.571932
# 19       0.044941       0.318969               0.644022
# 20       0.081480       0.535593               0.805720
# 21       0.415239       0.175161               0.935256
# 22       0.065152       0.218611               0.555811
# 23       0.127702       0.215253               0.746652
# 24       0.119719       0.138671               0.636977
# 25       0.327040       0.078444               0.443353
# 26       0.049949       0.450166               0.810944
# 27       0.158148       0.201287               0.773207
# 28       0.035175       0.143516               0.715598
# 29       0.074896       0.480996               0.522403
# 30       1.189178       0.841082               3.156484
#
#     13ARV1:total_intensity_std  13ARV1:log10_total_intensity_std
# 1                417114.485839                          0.084282  \
# 2                185657.501940                          0.040598
# 3                479575.896665                          0.096419
# 4                436647.098985                          0.076473
# 5                145498.336196                          0.028552
# 6                272678.665105                          0.045972
# 7                252015.105055                          0.052455
# 8                304219.675827                          0.050608
# 9                463003.159640                          0.080247
# 10               270718.399506                          0.044968
# 11                38899.804595                          0.006567
# 12               343729.895507                          0.059317
# 13               193310.288970                          0.032771
# 14               250585.322563                          0.044802
# 15               339659.049914                          0.067045
# 16               239891.140552                          0.044635
# 17               178489.847204                          0.030329
# 18               307684.022389                          0.049932
# 19               141864.094451                          0.025516
# 20               372062.385543                          0.066022
# 21               301959.303553                          0.047863
# 22               109936.102554                          0.019730
# 23               281278.399201                          0.049421
# 24               142303.128517                          0.024163
# 25               189552.709699                          0.038586
# 26               377945.937238                          0.072874
# 27               223376.323267                          0.041058
# 28               139650.823071                          0.028402
# 29               301350.101537                          0.062329
# 30               388159.904120                          0.073115
#
#     total_rms_size  xopt_runtime  xopt_error
# 1        15.821181      9.251255       False
# 2        15.600330     11.015657       False
# 3        21.120533      9.699843       False
# 4        21.366142     12.495802       False
# 5        23.221382      7.770248       False
# 6        23.597209      9.234790       False
# 7        22.089075      7.982702       False
# 8        24.197822      7.504057       False
# 9        24.407877      7.034743       False
# 10       24.482337      7.220196       False
# 11       24.578025      6.286747       False
# 12       24.631594      6.447165       False
# 13       24.889271      8.008152       False
# 14       25.480820      6.986542       False
# 15       25.365301      6.834347       False
# 16       25.004750      6.717962       False
# 17       24.818062      7.434536       False
# 18       24.986429      5.892197       False
# 19       24.885550      8.869420       False
# 20       23.544539     11.712576       False
# 21       25.980224      5.891860       False
# 22       25.280765      7.111135       False
# 23       26.441676      6.492353       False
# 24       25.674021     11.979916       False
# 25       21.966412     12.787573       False
# 26       25.247550      8.493112       False
# 27       26.877705      6.495474       False
# 28       24.783766      7.494676       False
# 29       26.037324      9.218237       False
# 30       23.235017      7.501775       False
#
# [30 rows x 31 columns]
