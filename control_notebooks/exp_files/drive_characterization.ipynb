# %%
from plugins.environments.awa_environment import AWAEnvironment
from plugins.interfaces.awa_interface import AWAInterface

# import data from csv file
import pandas as pd
variable_file = "plugins/environments/awa_variables.csv"
observable_file = "plugins/environments/awa_observables.csv"

env = AWAEnvironment(variable_file, observable_file, interface=AWAInterface(), target_charge=1.0)

# %%
env.variables
# Out:
# {'AWA:Drive:DS1:Ctrl': [500.0, 550.0],
#  'AWA:Drive:DS3:Ctrl': [180.0, 260.0],
#  'AWA:Bira3Ctrl:Ch03': [-5.0, 5.0],
#  'AWA:Bira3Ctrl:Ch04': [-5.0, 5.0],
#  'AWA:Bira3Ctrl:Ch05': [-5.0, 5.0],
#  'AWA:Bira3Ctrl:Ch06': [-5.0, 5.0],
#  'AWALLRF:K1:SetPhase': [236.0, 256.0],
#  'AWA:DAC0:Ch08': [4.5, 5.9]}

# %%
from xopt import Xopt, Evaluator, VOCS
from xopt.generators.bayesian import BayesianExplorationGenerator, UpperConfidenceBoundGenerator
from xopt.generators.bayesian.models.standard import StandardModelConstructor
from xopt.generators.bayesian.turbo import SafetyTurboController, OptimizeTurboController

import time

def evaluate(inputs):
    env.set_variables(inputs)
    time.sleep(2.0)
    result = env.get_observables(["13ARV1:Sx"])
    result["total_rms_size"] = (result["13ARV1:Sx"]**2 + result["13ARV1:Sy"]**2)**0.5
    return result

# use only one variable
vocs = VOCS(variables=env.variables,
            objectives={"total_rms_size":"MINIMIZE"},
            constraints={
                "13ARV1:bb_penalty":["LESS_THAN",0.0],
                "13ARV1:log10_total_intensity":["GREATER_THAN", 4.5]
            })

# %%
model_constructor = StandardModelConstructor(use_low_noise_prior=False)
generator = BayesianExplorationGenerator(
    vocs=vocs, 
    model_constructor=model_constructor,
    turbo_controller=SafetyTurboController(vocs=vocs, length=0.1)
)
evaluator = Evaluator(function=evaluate)
X = Xopt(vocs=vocs, evaluator=evaluator, generator=generator)
X.options.dump_file = "exploration_6_nd_filter.yml"

# %% [markdown]
# ##### X

# %%
# get the current quad setpoint
#current_val = env.get_variables(['AWA:Bira3Ctrl:Ch03'])
import numpy as np
default_pt = np.array([0, 0, 0, 0,5.9,550,190,246])
default_val = dict(zip(X.vocs.variable_names, default_pt))
default_val = pd.DataFrame(default_val, index=[0])
default_val
# Out:
#    AWA:Bira3Ctrl:Ch03  AWA:Bira3Ctrl:Ch04  AWA:Bira3Ctrl:Ch05
# 0                 0.0                 0.0                 0.0  \
#
#    AWA:Bira3Ctrl:Ch06  AWA:DAC0:Ch08  AWA:Drive:DS1:Ctrl  AWA:Drive:DS3:Ctrl
# 0                 0.0            5.9               550.0               190.0  \
#
#    AWALLRF:K1:SetPhase
# 0                246.0

# %%
# evaluate that point in xopt
X.evaluate_data(default_val)
# Out:
# "
#     Source File: ../cac.cpp line 1320
#     Current Time: Thu Jun 15 2023 16:33:32.399469443
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Thu Jun 15 2023 16:33:32.399378796
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Thu Jun 15 2023 16:33:32.399547309
# ..................................................................
# errlog: 4 messages were discarded
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Thu Jun 15 2023 16:33:32.399604626
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Thu Jun 15 2023 16:33:32.399724127
# ..................................................................
# "
#     Source File: ../cac.cpp line 1320
#     Current Time: Thu Jun 15 2023 16:33:32.399658602
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064
#    AWA:Bira3Ctrl:Ch03  AWA:Bira3Ctrl:Ch04  AWA:Bira3Ctrl:Ch05
# 1                 0.0                 0.0                 0.0  \
#
#    AWA:Bira3Ctrl:Ch06  AWA:DAC0:Ch08  AWA:Drive:DS1:Ctrl  AWA:Drive:DS3:Ctrl
# 1                 0.0            5.9               550.0               190.0  \
#
#    AWALLRF:K1:SetPhase  AWAVXI11ICT:Ch1  13ARV1:image1:ArraySize1_RBV  ...
# 1                246.0     9.383756e-10                        1200.0  ...  \
#
#    13ARV1:Cx_std  13ARV1:Cy_std  13ARV1:Sx_std  13ARV1:Sy_std
# 1       1.065201       0.640701       2.305501       1.321199  \
#
#    13ARV1:bb_penalty_std  13ARV1:total_intensity_std
# 1               5.914229               147542.155452  \
#
#    13ARV1:log10_total_intensity_std  total_rms_size  xopt_runtime  xopt_error
# 1                          0.041311       58.781718       9.21672       False
#
# [1 rows x 31 columns]

# %%
# evaluate a second nearby point
second_pt = np.array([0.1, 0.1, 0.1, 0.1, 5.8,540,185,245])
second_pt = dict(zip(X.vocs.variable_names, second_pt))
second_pt = pd.DataFrame(second_pt, index=[0])
X.evaluate_data(second_pt)
# Out:
#    AWA:Bira3Ctrl:Ch03  AWA:Bira3Ctrl:Ch04  AWA:Bira3Ctrl:Ch05
# 2                 0.1                 0.1                 0.1  \
#
#    AWA:Bira3Ctrl:Ch06  AWA:DAC0:Ch08  AWA:Drive:DS1:Ctrl  AWA:Drive:DS3:Ctrl
# 2                 0.1            5.8               540.0               185.0  \
#
#    AWALLRF:K1:SetPhase  AWAVXI11ICT:Ch1  13ARV1:image1:ArraySize1_RBV  ...
# 2                245.0     9.522137e-10                        1200.0  ...  \
#
#    13ARV1:Cx_std  13ARV1:Cy_std  13ARV1:Sx_std  13ARV1:Sy_std
# 2       0.830011       0.468287        5.27084       0.196187  \
#
#    13ARV1:bb_penalty_std  13ARV1:total_intensity_std
# 2              10.956383               209345.817651  \
#
#    13ARV1:log10_total_intensity_std  total_rms_size  xopt_runtime  xopt_error
# 2                          0.049094      101.925278     12.218099       False
#
# [1 rows x 31 columns]

# %%
X.data
# Out:
#    AWA:Bira3Ctrl:Ch03  AWA:Bira3Ctrl:Ch04  AWA:Bira3Ctrl:Ch05
# 1                 0.0                 0.0                 0.0  \
# 2                 0.1                 0.1                 0.1
#
#    AWA:Bira3Ctrl:Ch06  AWA:DAC0:Ch08  AWA:Drive:DS1:Ctrl  AWA:Drive:DS3:Ctrl
# 1                 0.0            5.9               550.0               190.0  \
# 2                 0.1            5.8               540.0               185.0
#
#    AWALLRF:K1:SetPhase  AWAVXI11ICT:Ch1  13ARV1:image1:ArraySize1_RBV  ...
# 1                246.0     9.383756e-10                        1200.0  ...  \
# 2                245.0     9.522137e-10                        1200.0  ...
#
#    13ARV1:Cx_std  13ARV1:Cy_std  13ARV1:Sx_std  13ARV1:Sy_std
# 1       1.065201       0.640701       2.305501       1.321199  \
# 2       0.830011       0.468287       5.270840       0.196187
#
#    13ARV1:bb_penalty_std  13ARV1:total_intensity_std
# 1               5.914229               147542.155452  \
# 2              10.956383               209345.817651
#
#    13ARV1:log10_total_intensity_std  total_rms_size  xopt_runtime  xopt_error
# 1                          0.041311       58.781718      9.216720       False
# 2                          0.049094      101.925278     12.218099       False
#
# [2 rows x 31 columns]

# %%
# run exploration
n_steps = 200
X.generator.numerical_optimizer.max_iter = 100
for i in range(n_steps):
    print(i)
    start = time.time()
    X.step()
    print(time.time() - start)
# Out:
# 0
# 21.868786573410034
# 1
# 16.021493673324585
# 2
# 18.9787437915802
# 3
# 13.02622389793396
# 4
# 16.044309377670288
# 5
# 10.941648244857788
# 6
# 12.519606828689575
# 7
# 16.511353015899658
# 8
# 19.48990797996521
# 9
# 11.011896848678589
# 10
# 17.98816990852356
# 11
# 12.813816785812378
# 12
# 15.713447093963623
# 13
# 16.508463621139526
# 14
# 10.270737409591675
# 15
# 12.478586435317993
# 16
# 13.023021221160889
# 17
# 15.740731477737427
# 18
# 15.775237798690796
# 19
# 15.508583784103394
# 20
# 22.501044511795044
# 21
# 17.735605239868164
# 22
# 16.504708528518677
# 23
# 12.492563724517822
# 24
# 11.771834135055542
# 25
# 13.084902048110962
# 26
# 13.68036699295044
# 27
# 14.015722274780273
# 28
# 13.481832027435303
# 29
# 17.036664724349976
# 30
# 12.547338485717773
# 31
# 13.454883337020874
# 32
# 14.331367492675781
# 33
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Xopt/xopt/utils.py:132, in safe_call(func, *args, **kwargs)
#     131 try:
# --> 132     result = func(*args, **kwargs)
#     133     outputs["exception"] = None
#
# Cell In[3], line 11, in evaluate(inputs)
#      10 time.sleep(2.0)
# ---> 11 result = env.get_observables(["13ARV1:Sx"])
#      12 result["total_rms_size"] = (result["13ARV1:Sx"]**2 + result["13ARV1:Sy"]**2)**0.5
#
# File ~/awa-badger/plugins/environments/environment.py:44, in validate_observable_names.<locals>.validate(interface, observable_names)
#      43         raise ValueError(f"Observable name: {name} not found in interface")
# ---> 44 return func(interface, observable_names)
#
# File ~/awa-badger/plugins/environments/awa_environment.py:74, in AWAEnvironment.get_observables(self, observable_names)
#      73 if screen_name in base_observable_names:
# ---> 74     measurement = self.get_screen_measurement(
#      75         screen_name, observable_names
#      76     )
#      77 else:
#      78     # otherwise do normal epics communication
#
# File ~/awa-badger/plugins/environments/awa_environment.py:127, in AWAEnvironment.get_screen_measurement(self, screen_name, extra_pvs, visualize)
#     125 threshold = 150
# --> 127 beam_data = get_beam_data(img, roi_data, threshold, visualize=visualize)
#     128 measurement.update(
#     129     {f"{screen_name}:{name}": beam_data[name] for name in beam_data}
#     130 )
#
# File ~/awa-badger/plugins/environments/awa_environment.py:200, in get_beam_data(img, roi_data, threshold, visualize)
#     198 total_intensity = np.sum(thresholded_image)
# --> 200 cx, cy, sx, sy = calculate_stats(thresholded_image)
#     201 c = np.array((cx, cy))
#
# File ~/awa-badger/plugins/environments/awa_environment.py:269, in calculate_stats(img)
#     268 m00 = np.sum(img)
# --> 269 m10 = np.sum(col_coords[:, np.newaxis] * img.T)
#     270 m01 = np.sum(row_coords[:, np.newaxis] * img)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[9], line 7
#       5 print(i)
#       6 start = time.time()
# ----> 7 X.step()
#       8 print(time.time() - start)
#
# File ~/Xopt/xopt/base.py:234, in Xopt.step(self)
#     231     self.n_unfinished_futures = self.process_futures()
#     232 else:
#     233     # Evaluate data
# --> 234     self.evaluate_data(new_samples)
#     236 # dump data to file if specified
#     237 self.dump_state()
#
# File ~/Xopt/xopt/base.py:134, in Xopt.evaluate_data(self, input_data)
#     132 logger.debug(f"Evaluating {len(input_data)} inputs")
#     133 input_data = self.prepare_input_data(input_data)
# --> 134 output_data = self.evaluator.evaluate_data(input_data)
#     136 if self.options.strict:
#     137     validate_outputs(output_data)
#
# File ~/Xopt/xopt/evaluator.py:113, in Evaluator.evaluate_data(self, input_data)
#     104     kwargs = [self.function_kwargs] * len(inputs)
#     106     output_data = self.executor.map(
#     107         safe_function1_for_map,
#     108         funcs,
#     109         inputs,
#     110         kwargs,
#     111     )
# --> 113 return pd.DataFrame(output_data, index=input_data.index)
#
# File ~/miniconda3/envs/awa-badger/lib/python3.9/site-packages/pandas/core/frame.py:774, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772         data = np.asarray(data)
#     773     else:
# --> 774         data = list(data)
#     775 if len(data) > 0:
#     776     if is_dataclass(data[0]):
#
# File ~/Xopt/xopt/evaluator.py:164, in safe_function1_for_map(function, inputs, kwargs)
#     160 def safe_function1_for_map(function, inputs, kwargs):
#     161     """
#     162     Safely call the function, handling exceptions.
#     163     """
# --> 164     return safe_function(function, inputs, **kwargs)
#
# File ~/Xopt/xopt/evaluator.py:168, in safe_function(function, *args, **kwargs)
#     167 def safe_function(function, *args, **kwargs):
# --> 168     safe_outputs = safe_call(function, *args, **kwargs)
#     169     return process_safe_outputs(safe_outputs)
#
# File ~/Xopt/xopt/utils.py:143, in safe_call(func, *args, **kwargs)
#     141     outputs["traceback"] = error_str
#     142 finally:
# --> 143     outputs["result"] = result
#     144     outputs["runtime"] = time.perf_counter() - t
#     145 return outputs
#
# UnboundLocalError: local variable 'result' referenced before assignment

# %%
X.data

# %%
X.data.plot(y=X.vocs.variable_names[:4])

# %%
X.data.plot(y=X.vocs.variable_names[4])

# %%
X.data.plot(y=X.vocs.variable_names[5:])

# %%
import torch
import matplotlib.pyplot as plt
test_x = torch.linspace(-2,2, 100)
model = X.generator.train_model()

fig,ax = plt.subplots(2,1, sharex="all")
fig.set_size_inches(6,6)
with torch.no_grad():
    post = model.posterior(test_x.reshape(-1,1,1).double())
    for i in range(post.event_shape[-1]):
        mean = post.mean[...,i].squeeze()
        l,u = post.mvn.confidence_region()
        ax[0].plot(test_x, mean,f"C{i}", label=generator.vocs.output_names[i])
        ax[0].fill_between(test_x, l[...,i].squeeze(), u[...,i].squeeze(), alpha=0.5)


    acq = generator.get_acquisition(model)(test_x.reshape(-1,1,1).double())

    ax[1].plot(test_x, acq, label='Acquisition Function')
    ax[1].legend()

# %%
from emitopt.utils import get_valid_emittance_samples
beam_energy = 45*10**-3 # GeV 
q_len = 0.12 # m
distance = 1.33-0.265 #m

data = X.data

data["grad"] = data["AWA:Bira3Ctrl:Ch04"] * 100*8.93e-3
data["int_grad"] = data["grad"]*q_len*10

data["sx_m"] = 3.9232781168265036e-05 * data["13ARV1:Sx"]

data

# %%
from gpytorch.likelihoods import GaussianLikelihood
from gpytorch.priors import GammaPrior
from gpytorch.kernels import MaternKernel, PolynomialKernel, ScaleKernel
from gpytorch import ExactMarginalLogLikelihood

from botorch.models.gp_regression import SingleTaskGP
from botorch.models.transforms import Normalize, Standardize
from botorch.fit import fit_gpytorch_mll

train_x = torch.tensor(data.dropna()["int_grad"].to_numpy()).double().unsqueeze(1)
train_y = torch.tensor(data.dropna()["sx_m"].to_numpy()).double().unsqueeze(1)

print(train_x.shape)
print(train_y.shape)
input_transform = Normalize(1)
outcome_transform = Standardize(1)
covar_module = ScaleKernel(PolynomialKernel(power=2))
#covar_module = MaternKernel()

model = SingleTaskGP(train_x, 
                     train_y, 
                     input_transform=input_transform,
                     outcome_transform=outcome_transform, 
                     covar_module = covar_module
                     )

mll = ExactMarginalLogLikelihood(model.likelihood, model)
fit_gpytorch_mll(mll)


(emits_at_target_valid,
 emits_sq_at_target,
 is_valid,
 sample_validity_rate) = get_valid_emittance_samples(model, beam_energy,
                                                     q_len,
                                                     distance, n_samples=50, n_steps_quad_scan=10, visualize=True)

# %%
plt.hist(emits_at_target_valid.flatten()*90)
plt.title('Distribution of Sampled Emittances')
plt.xlabel('Emittance')
plt.ylabel('Probability Density')
