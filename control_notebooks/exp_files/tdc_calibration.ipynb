# %% [markdown]
# # TDC Calibration

# %% [markdown]
# ## define the diagnostic

# %%
from measurement import get_DYG14, set_camera, set_background

save_image_location = "/home/awa/awa_data/12-07_6DReconstruction/tdc_calibration"
image_diagnostic = get_DYG14()
image_diagnostic.save_image_location = save_image_location

# %%
set_background(image_diagnostic)
# Out:
# "
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935342306
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935271537
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064errlog: 4 messages were discarded
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935390547
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "errlog: 1 messages were discarded
# "
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935449691
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935491901
# ..................................................................
# CA.Client.Exception...............................................
# "
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935573536
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935530089
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064errlog: 3 messages were discarded
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935630472
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:19:53.935668581
# ..................................................................
# array([[ 2124.8,  3456. ,  2688. , ...,  2009.6,  1984. ,  2060.8],
#        [ 2086.4,  1990.4,  2406.4, ...,  5606.4,  8630.4,  1984. ],
#        [ 7782.4,  2748.8,  1971.2, ..., 17312. ,  3062.4,  5427.2],
#        ...,
#        [ 2342.4,  2000. ,  2076.8, ...,  2044.8,  2035.2,  2585.6],
#        [ 2163.2,  1987.2,  2025.6, ...,  2169.6,  5046.4,  1984. ],
#        [ 1971.2,  2969.6,  5872. , ...,  2012.8,  2547.2,  2636.8]])

# %%
image_diagnostic.test_measurement()
# Out:
# 5.537276786832282e-10
# charge error 5.5e-10 outside atol 1e-10
# 1.1678815757844844e-10
# charge error 1.2e-10 outside atol 1e-10
# 4.1984200798802815e-10
# charge error 4.2e-10 outside atol 1e-10
# 1.6881718254350148e-10
# charge error 1.7e-10 outside atol 1e-10
# 1.461096454066697e-10
# charge error 1.5e-10 outside atol 1e-10
# 4.2490557139271433e-10
# charge error 4.2e-10 outside atol 1e-10
# 1.4013644877283186e-10
# charge error 1.4e-10 outside atol 1e-10
# 4.4943830570140806e-11
# displaying image
# fitting image
# {'Cx': nan,
#  'Cy': nan,
#  'Sx': nan,
#  'Sy': nan,
#  'bb_penalty': nan,
#  'total_intensity': 19840584.0,
#  'log10_total_intensity': 7.297554451298234,
#  'AWAVXI11ICT:Ch4': 1.2449438305701408e-09}

# %% [markdown]
# ### Define the evaluator

# %%
from epics import caput, caget
from xopt import Evaluator
import time
import numpy as np

def evaluate_function(inputs: dict) -> dict:
    global image_diagnostic
    # caput values
    for name, val in inputs.items():
        caput(name, val)
        print(name, val)

    # wait for changes to occur - use small wait time for interpolated measurements
    time.sleep(5)

    results = image_diagnostic.measure_beamsize(5, **inputs)

    # get other PV's NOTE: Measurements not synchronous with beamsize measurements!
    results = results

    # add total beam size
    results["total_size"] = np.sqrt(np.array(results["Sx"]) ** 2 + np.array(results["Sy"]) ** 2)
    return results

evaluator = Evaluator(function=evaluate_function)

# %% [markdown]
# ### Define VOCS
# Here we define the names and ranges of input parameters, the names and settings of
# objectives, and the names and settings of constraints. Note that the keys here should
#  be referenced in the evaluate function above.

# %%
from xopt import VOCS

TDC_PHASE_PV = "AWALLRF:K5:SetPhase"

# define control PVs and ranges here
vocs = VOCS(
    variables = {
        TDC_PHASE_PV: [130, 170], # Quad 4:9
    },
    objectives = {"total_size":"MINIMIZE"},
)

# %% [markdown]
# ### Define the Generator (NOT USED HERE)

# %%
from xopt.generators import get_generator
generator = get_generator("random")(vocs=vocs)

# %% [markdown]
# ###  Combine into Xopt object

# %%
from xopt import Xopt
dump_filename = "/home/awa/awa_data/12-05_6DReconstruction/tdc_calibration/tdc_calibration.yml"
X = Xopt(vocs=vocs, generator=generator, evaluator=evaluator, dump_file=dump_filename)

# %% [markdown]
# ## Introspection
# Objects in Xopt can be printed to a string or dumped to a text file for easy
# introspection of attributes and current configuration.

# %%
# Convenient representation of the state.
X
# Out:
#             Xopt
# ________________________________
# Version: 2.1.0+27.g53bd9d64.dirty
# Data size: 0
# Config as YAML:
# dump_file: /home/awa/awa_data/12-05_6DReconstruction/tdc_calibration/tdc_calibration.yml
# evaluator:
#   function: __main__.evaluate_function
#   function_kwargs: {}
#   max_workers: 1
#   vectorized: false
# generator:
#   name: random
#   supports_batch_generation: true
#   supports_multi_objective: true
# max_evaluations: null
# serialize_inline: false
# serialize_torch: false
# strict: true
# vocs:
#   constants: {}
#   constraints: {}
#   objectives:
#     total_size: MINIMIZE
#   observables: []
#   variables:
#     AWALLRF:K5:SetPhase:
#     - 130.0
#     - 170.0

# %% [markdown]
# ### Do scan

# %%
# examine the data stored in Xopt
tdc_phase_values = np.linspace(150,160,10)
X.evaluate_data({TDC_PHASE_PV: tdc_phase_values})
# Out:
# AWALLRF:K5:SetPhase 150.0
# 1.261137920296409e-10
# charge error 1.3e-10 outside atol 1e-10
# 9.088892092499496e-11
# fitting image
# 1.444529882150637e-10
# charge error 1.4e-10 outside atol 1e-10
# 3.248042916806174e-10
# charge error 3.2e-10 outside atol 1e-10
# 1.9906177759648198e-10
# charge error 2e-10 outside atol 1e-10
# 2.6475459067288115e-10
# charge error 2.6e-10 outside atol 1e-10
# 2.446623739074946e-10
# charge error 2.4e-10 outside atol 1e-10
# 8.185237663884871e-11
# fitting image
# 5.4758053851439914e-11
# fitting image
# 2.860220805390803e-10
# charge error 2.9e-10 outside atol 1e-10
# 1.6488969902429243e-10
# charge error 1.6e-10 outside atol 1e-10
# 3.0347826330750967e-10
# charge error 3e-10 outside atol 1e-10
# 2.6179164162948216e-10
# charge error 2.6e-10 outside atol 1e-10
# 1.7662485103488303e-10
# charge error 1.8e-10 outside atol 1e-10
# 2.258979340129132e-11
# fitting image
# 3.4705252668611207e-10
# charge error 3.5e-10 outside atol 1e-10
# 1.464978007373037e-10
# charge error 1.5e-10 outside atol 1e-10
# 8.159750898556977e-11
# fitting image
# AWALLRF:K5:SetPhase 151.11111111111111
# 2.2535097076540018e-10
# charge error 2.3e-10 outside atol 1e-10
# 2.4258591145179655e-11
# fitting image
# 2.0364982820635323e-10
# charge error 2e-10 outside atol 1e-10
# 2.0027847794834548e-10
# charge error 2e-10 outside atol 1e-10
# 4.2457732290296384e-10
# charge error 4.2e-10 outside atol 1e-10
# 4.2560489884779497e-10
# charge error 4.3e-10 outside atol 1e-10
# 2.8329058374619497e-10
# charge error 2.8e-10 outside atol 1e-10
# 4.40869940271977e-10
# charge error 4.4e-10 outside atol 1e-10
# 3.940325683795873e-12
# fitting image
# 1.347919005348342e-10
# charge error 1.3e-10 outside atol 1e-10
# 1.4662748604497252e-10
# charge error 1.5e-10 outside atol 1e-10
# 2.1292863185200022e-10
# charge error 2.1e-10 outside atol 1e-10
# 7.351078915369271e-10
# charge error 7.4e-10 outside atol 1e-10
# 2.7065797394930883e-10
# charge error 2.7e-10 outside atol 1e-10
# 2.1373152743474856e-10
# charge error 2.1e-10 outside atol 1e-10
# 1.9777483103631528e-10
# charge error 2e-10 outside atol 1e-10
# 5.30202403634109e-10
# charge error 5.3e-10 outside atol 1e-10
# 4.393876943567842e-11
# fitting image
# 8.838797579019025e-11
# fitting image
# 3.5094218532392625e-10
# charge error 3.5e-10 outside atol 1e-10
# 1.9516071490938273e-11
# fitting image
# AWALLRF:K5:SetPhase 152.22222222222223
# 8.991087756295608e-11
# fitting image
# 1.5471300474150298e-10
# charge error 1.5e-10 outside atol 1e-10
# 3.0602784043267793e-10
# charge error 3.1e-10 outside atol 1e-10
# 3.1862983008745515e-10
# charge error 3.2e-10 outside atol 1e-10
# 3.042572757459758e-10
# charge error 3e-10 outside atol 1e-10
# 1.627213761423431e-11
# fitting image
# 5.0984571635096863e-11
# fitting image
# 3.5499214941149035e-10
# charge error 3.5e-10 outside atol 1e-10
# 2.4364920744128684e-10
# charge error 2.4e-10 outside atol 1e-10
# 5.705102183256673e-10
# charge error 5.7e-10 outside atol 1e-10
# 4.656803606964381e-10
# charge error 4.7e-10 outside atol 1e-10
# 4.169538081150231e-10
# charge error 4.2e-10 outside atol 1e-10
# 7.25100637826852e-11
# fitting image
# 2.766162933630144e-10
# charge error 2.8e-10 outside atol 1e-10
# 1.2372812272388037e-10
# charge error 1.2e-10 outside atol 1e-10
# 7.546717642071608e-11
# fitting image
# AWALLRF:K5:SetPhase 153.33333333333334
# 3.1389901813458323e-10
# charge error 3.1e-10 outside atol 1e-10
# 2.2005999033077745e-10
# charge error 2.2e-10 outside atol 1e-10
# 2.3471262891315813e-10
# charge error 2.3e-10 outside atol 1e-10
# 8.147636186052682e-11
# fitting image
# 2.532369142850443e-10
# charge error 2.5e-10 outside atol 1e-10
# 1.8436771176304944e-10
# charge error 1.8e-10 outside atol 1e-10
# 3.145420411184667e-10
# charge error 3.1e-10 outside atol 1e-10
# 1.6907750316281402e-13
# fitting image
# 8.453387310742556e-11
# fitting image
# 1.1136388946650064e-10
# charge error 1.1e-10 outside atol 1e-10
# 1.5689694134643514e-10
# charge error 1.6e-10 outside atol 1e-10
# 2.5727246889401105e-10
# charge error 2.6e-10 outside atol 1e-10
# 4.141757841684933e-11
# fitting image
# 6.887574053966599e-11
# fitting image
# AWALLRF:K5:SetPhase 154.44444444444446
# 1.8706318485936999e-10
# charge error 1.9e-10 outside atol 1e-10
# 3.686856570725468e-10
# charge error 3.7e-10 outside atol 1e-10
# 4.3950944878593884e-11
# fitting image
# 2.506895711956125e-10
# charge error 2.5e-10 outside atol 1e-10
# 1.008098469620745e-10
# charge error 1e-10 outside atol 1e-10
# 3.2397347773304335e-10
# charge error 3.2e-10 outside atol 1e-10
# 2.0387184168183062e-10
# charge error 2e-10 outside atol 1e-10
# 4.290550683873834e-10
# charge error 4.3e-10 outside atol 1e-10
# 2.7857662085232848e-12
# fitting image
# 2.9070889266268895e-11
# fitting image
# 3.229805920414621e-10
# charge error 3.2e-10 outside atol 1e-10
# 1.8456764327905143e-10
# charge error 1.8e-10 outside atol 1e-10
# 1.1745819833478862e-10
# charge error 1.2e-10 outside atol 1e-10
# 8.319606052112286e-11
# fitting image
# 3.7969900170830864e-10
# charge error 3.8e-10 outside atol 1e-10
# 1.7669016143023294e-10
# charge error 1.8e-10 outside atol 1e-10
# 3.5754983186842827e-10
# charge error 3.6e-10 outside atol 1e-10
# 2.498299731813646e-10
# charge error 2.5e-10 outside atol 1e-10
# 1.6272737663730177e-10
# charge error 1.6e-10 outside atol 1e-10
# 2.4149362205211305e-10
# charge error 2.4e-10 outside atol 1e-10
# 1.2734142868943247e-11
# fitting image
# AWALLRF:K5:SetPhase 155.55555555555554
# 9.902847516637368e-11
# fitting image
# 3.238762137522594e-10
# charge error 3.2e-10 outside atol 1e-10
# 1.7006090066779098e-10
# charge error 1.7e-10 outside atol 1e-10
# 9.143107755846374e-11
# fitting image
# 4.750618318773086e-10
# charge error 4.8e-10 outside atol 1e-10
# 4.715705387387392e-11
# fitting image
# 2.854231865835052e-10
# charge error 2.9e-10 outside atol 1e-10
# 2.555649456763007e-10
# charge error 2.6e-10 outside atol 1e-10
# 1.5780203672291204e-10
# charge error 1.6e-10 outside atol 1e-10
# 1.3999055280168495e-10
# charge error 1.4e-10 outside atol 1e-10
# 4.784309480995932e-10
# charge error 4.8e-10 outside atol 1e-10
# 4.006801031867186e-10
# charge error 4e-10 outside atol 1e-10
# 1.4338625394552672e-10
# charge error 1.4e-10 outside atol 1e-10
# 3.471587965910121e-10
# charge error 3.5e-10 outside atol 1e-10
# 3.3545739935062703e-10
# charge error 3.4e-10 outside atol 1e-10
# 1.6072626029248652e-10
# charge error 1.6e-10 outside atol 1e-10
# 1.4758391518907135e-10
# charge error 1.5e-10 outside atol 1e-10
# 6.547780536012891e-11
# fitting image
# 1.6434844298322299e-10
# charge error 1.6e-10 outside atol 1e-10
# 2.0204814204264945e-10
# charge error 2e-10 outside atol 1e-10
# 2.3975954880347277e-10
# charge error 2.4e-10 outside atol 1e-10
# 1.5206256126589055e-10
# charge error 1.5e-10 outside atol 1e-10
# 2.585274269781602e-10
# charge error 2.6e-10 outside atol 1e-10
# 3.0652496744544087e-10
# charge error 3.1e-10 outside atol 1e-10
# 3.028397432856821e-10
# charge error 3e-10 outside atol 1e-10
# 9.489518883516202e-11
# fitting image
# AWALLRF:K5:SetPhase 156.66666666666666
# 5.274432921282724e-11
# fitting image
# 7.597420995001848e-11
# fitting image
# 4.66126283140583e-11
# fitting image
# 4.501424397706932e-10
# charge error 4.5e-10 outside atol 1e-10
# 4.56881572807693e-10
# charge error 4.6e-10 outside atol 1e-10
# 9.323046120244834e-11
# fitting image
# 1.8865092928595202e-10
# charge error 1.9e-10 outside atol 1e-10
# 2.792883510565647e-10
# charge error 2.8e-10 outside atol 1e-10
# 2.3755129620334467e-10
# charge error 2.4e-10 outside atol 1e-10
# 4.7878428397802315e-11
# fitting image
# AWALLRF:K5:SetPhase 157.77777777777777
# 1.1336050284922803e-10
# charge error 1.1e-10 outside atol 1e-10
# 2.0306220910128382e-10
# charge error 2e-10 outside atol 1e-10
# 1.111963792774083e-10
# charge error 1.1e-10 outside atol 1e-10
# 1.0795064421590733e-10
# charge error 1.1e-10 outside atol 1e-10
# 3.888601313996651e-11
# fitting image
# 2.364597781970921e-10
# charge error 2.4e-10 outside atol 1e-10
# 1.380385361887647e-10
# charge error 1.4e-10 outside atol 1e-10
# 6.013639175028254e-11
# fitting image
# 1.891165355642036e-10
# charge error 1.9e-10 outside atol 1e-10
# 5.820711231493986e-10
# charge error 5.8e-10 outside atol 1e-10
# 3.270854922663081e-10
# charge error 3.3e-10 outside atol 1e-10
# 4.536808673668952e-10
# charge error 4.5e-10 outside atol 1e-10
# 5.883096560028471e-11
# fitting image
# 1.806829204542047e-10
# charge error 1.8e-10 outside atol 1e-10
# 1.510579329823275e-10
# charge error 1.5e-10 outside atol 1e-10
# 6.201365919279605e-11
# fitting image
# 2.438239223696942e-10
# charge error 2.4e-10 outside atol 1e-10
# 2.1981122127996557e-12
# fitting image
# AWALLRF:K5:SetPhase 158.88888888888889
# 4.796377419348913e-10
# charge error 4.8e-10 outside atol 1e-10
# 2.6920081542282017e-10
# charge error 2.7e-10 outside atol 1e-10
# 6.836193512193407e-11
# fitting image
# 3.4616994611997465e-10
# charge error 3.5e-10 outside atol 1e-10
# 3.002136158052963e-10
# charge error 3e-10 outside atol 1e-10
# 2.7699287019110277e-11
# fitting image
# 2.1851907670972908e-10
# charge error 2.2e-10 outside atol 1e-10
# 4.2043279661186855e-10
# charge error 4.2e-10 outside atol 1e-10
# 1.8808355606488777e-10
# charge error 1.9e-10 outside atol 1e-10
# 2.552641478098831e-10
# charge error 2.6e-10 outside atol 1e-10
# 3.6553088184488715e-10
# charge error 3.7e-10 outside atol 1e-10
# 1.888184394750458e-10
# charge error 1.9e-10 outside atol 1e-10
# 4.849083123960633e-11
# fitting image
# 3.438554236149723e-10
# charge error 3.4e-10 outside atol 1e-10
# 2.3081846731325848e-10
# charge error 2.3e-10 outside atol 1e-10
# 1.174865495505356e-10
# charge error 1.2e-10 outside atol 1e-10
# 7.652490476611168e-11
# fitting image
# 1.165233834086286e-10
# charge error 1.2e-10 outside atol 1e-10
# 2.8844287294900823e-10
# charge error 2.9e-10 outside atol 1e-10
# 3.3354273987760123e-10
# charge error 3.3e-10 outside atol 1e-10
# 8.19266580677228e-11
# fitting image
# AWALLRF:K5:SetPhase 160.0
# 2.144898262476753e-10
# charge error 2.1e-10 outside atol 1e-10
# 7.011268677555595e-11
# fitting image
# 3.305833932038617e-10
# charge error 3.3e-10 outside atol 1e-10
# 6.911526775670204e-10
# charge error 6.9e-10 outside atol 1e-10
# 1.8813759160973685e-10
# charge error 1.9e-10 outside atol 1e-10
# 4.348904394912401e-10
# charge error 4.3e-10 outside atol 1e-10
# 8.426999953000338e-11
# fitting image
# 4.0621827879381935e-10
# charge error 4.1e-10 outside atol 1e-10
# 2.295648426723989e-10
# charge error 2.3e-10 outside atol 1e-10
# 1.702599315913924e-10
# charge error 1.7e-10 outside atol 1e-10
# 1.7683605740138647e-10
# charge error 1.8e-10 outside atol 1e-10
# 2.9190788481812993e-10
# charge error 2.9e-10 outside atol 1e-10
# 1.4687828358707845e-10
# charge error 1.5e-10 outside atol 1e-10
# 1.6955746950814443e-10
# charge error 1.7e-10 outside atol 1e-10
# 3.50303665302099e-10
# charge error 3.5e-10 outside atol 1e-10
# 2.424752677838181e-10
# charge error 2.4e-10 outside atol 1e-10
# 2.463820376775059e-10
# charge error 2.5e-10 outside atol 1e-10
# 2.362134487264378e-10
# charge error 2.4e-10 outside atol 1e-10
# 2.556488299697161e-11
# fitting image
# 3.216152939412211e-10
# charge error 3.2e-10 outside atol 1e-10
# 2.9818548168802893e-10
# charge error 3e-10 outside atol 1e-10
# 3.872660828261663e-11
# fitting image
# 3.52931593967341e-10
# charge error 3.5e-10 outside atol 1e-10
# 2.5835528462823723e-11
# fitting image
#     AWALLRF:K5:SetPhase          Cx          Cy        Sx         Sy
# 0            150.000000  325.897266  181.826218   4.70962   27.66173  \
# 1            150.000000  323.832781  191.283468  5.248018  26.050978
# 2            150.000000  324.783155  193.457369  5.727509   30.14706
# 3            150.000000  325.492581  207.609898  5.001117  21.820188
# 4            150.000000  324.869358  200.051333  5.069611  27.071373
# 5            151.111111  323.909481   234.92249  4.961035   29.77649
# 6            151.111111  324.351739  256.157121  4.747436  31.244119
# 7            151.111111  324.461784  236.288481  4.738529  28.105669
# 8            151.111111  324.808092  227.222556   5.19075  25.239284
# 9            151.111111  324.985607  239.974164  4.895717  28.537104
# 10           152.222222         NaN         NaN       NaN        NaN
# 11           152.222222  323.413197  267.505617  4.960429  26.213586
# 12           152.222222  323.616446  278.818633   5.00525  25.809428
# 13           152.222222         NaN         NaN       NaN        NaN
# 14           152.222222  324.761322  273.842878  5.034548  26.287081
# 15           153.333333  323.354534  315.216797  5.573764  18.221964
# 16           153.333333  324.750524  301.639267  5.375155  23.881265
# 17           153.333333  324.101759  312.811004   5.22223   19.10848
# 18           153.333333  323.099188  301.295064  5.416451  21.578689
# 19           153.333333         NaN         NaN       NaN        NaN
# 20           154.444444         NaN         NaN       NaN        NaN
# 21           154.444444         NaN         NaN       NaN        NaN
# 22           154.444444         NaN         NaN       NaN        NaN
# 23           154.444444         NaN         NaN       NaN        NaN
# 24           154.444444         NaN         NaN       NaN        NaN
# 25           155.555556         NaN         NaN       NaN        NaN
# 26           155.555556         NaN         NaN       NaN        NaN
# 27           155.555556         NaN         NaN       NaN        NaN
# 28           155.555556         NaN         NaN       NaN        NaN
# 29           155.555556         NaN         NaN       NaN        NaN
# 30           156.666667         NaN         NaN       NaN        NaN
# 31           156.666667  323.590789  465.239046  4.951238  16.166381
# 32           156.666667         NaN         NaN       NaN        NaN
# 33           156.666667         NaN         NaN       NaN        NaN
# 34           156.666667         NaN         NaN       NaN        NaN
# 35           157.777778  322.064414   483.93448  6.357432  23.133305
# 36           157.777778  322.396025  476.392474  5.101264  19.522724
# 37           157.777778  322.435389  483.679163  5.503813  27.938568
# 38           157.777778  322.812188   494.47912  4.789363  34.490815
# 39           157.777778  322.783697  477.103207  4.996579  21.277394
# 40           158.888889   324.07942  507.507202  5.193652  27.354408
# 41           158.888889  322.475889  540.004274  6.078297  37.029763
# 42           158.888889         NaN         NaN       NaN        NaN
# 43           158.888889  321.603814   536.75359  6.037539  33.469461
# 44           158.888889  322.823268  515.487295  5.912283   35.28878
# 45           160.000000  322.780194  558.222155  4.906636  27.157094
# 46           160.000000  323.188473  542.169868    4.7495  31.711171
# 47           160.000000         NaN         NaN       NaN        NaN
# 48           160.000000         NaN         NaN       NaN        NaN
# 49           160.000000  323.839086  546.119046    6.0332  25.336478
#
#     bb_penalty total_intensity log10_total_intensity AWAVXI11ICT:Ch4
# 0   -95.947872      31536131.2              7.498808             0.0  \
# 1  -109.451255      36417148.8              7.561306             0.0
# 2   -99.403294      35039201.6              7.544554             0.0
# 3  -138.427316      29920358.4              7.475967             0.0
# 4  -115.343852      32934235.2              7.517648             0.0
# 5  -141.526857      31716736.0              7.501288             0.0
# 6  -158.230017      32740574.4              7.515086             0.0
# 7  -148.020639      33336124.8              7.522915             0.0
# 8  -147.362148      30370835.2              7.482457             0.0
# 9  -150.375087      31399120.0              7.496917             0.0
# 10         NaN      25384318.4              7.404566             0.0
# 11 -183.614495      29891868.8              7.475553             0.0
# 12 -195.731628      29011564.8              7.462571             0.0
# 13         NaN      26314155.2              7.420189             0.0
# 14  -189.81824      30528233.6              7.484702             0.0
# 15 -250.592676      27824065.6              7.444421             0.0
# 16 -223.063117      30100512.0              7.478574             0.0
# 17 -246.749712      28126289.6              7.449112             0.0
# 18 -228.629502      27358633.6              7.437094             0.0
# 19         NaN      24624838.4              7.391373             0.0
# 20         NaN      23989198.4              7.380016             0.0
# 21         NaN      20156113.6              7.304407             0.0
# 22         NaN      22159820.8              7.345566             0.0
# 23         NaN      19277156.8              7.285043             0.0
# 24         NaN      18504260.8              7.267272             0.0
# 25         NaN      19135073.6               7.28183             0.0
# 26         NaN      19110510.4              7.281272             0.0
# 27         NaN      19378945.6               7.28733             0.0
# 28         NaN      17552099.2              7.244329             0.0
# 29         NaN      20003148.8              7.301098             0.0
# 30         NaN      22599987.2              7.354108             0.0
# 31 -181.142593      25256224.0              7.402368             0.0
# 32         NaN      20306494.4              7.307635             0.0
# 33         NaN      20360700.8              7.308793             0.0
# 34         NaN      21254910.4              7.327459             0.0
# 35  -141.30257      27195849.6              7.434503             0.0
# 36 -160.127631      25095115.2              7.399589             0.0
# 37 -128.083989      29971059.2              7.476702             0.0
# 38  -98.590231      27762264.0              7.443455             0.0
# 39 -154.455447      26133166.4              7.417192             0.0
# 40 -106.861424      29978334.4              7.476807             0.0
# 41  -45.449152      39429937.6              7.595826             0.0
# 42         NaN      24369923.2              7.386854             0.0
# 43   -59.09612      31014550.4              7.491565             0.0
# 44  -74.954503      30186564.8              7.479814             0.0
# 45  -57.286441      29206926.4              7.465486             0.0
# 46  -59.777399      30125340.8              7.478932             0.0
# 47         NaN      22932908.8              7.360459             0.0
# 48         NaN      28651158.4              7.457142             0.0
# 49  -74.295623      28151534.4              7.449502             0.0
#
#                                         save_filename total_size
# 0   /home/awa/awa_data/12-05_6DReconstruction/beam...   28.05979  \
# 1   /home/awa/awa_data/12-05_6DReconstruction/beam...  26.574332
# 2   /home/awa/awa_data/12-05_6DReconstruction/beam...  30.686309
# 3   /home/awa/awa_data/12-05_6DReconstruction/beam...  22.385973
# 4   /home/awa/awa_data/12-05_6DReconstruction/beam...  27.541972
# 5   /home/awa/awa_data/12-05_6DReconstruction/beam...  30.186938
# 6   /home/awa/awa_data/12-05_6DReconstruction/beam...  31.602739
# 7   /home/awa/awa_data/12-05_6DReconstruction/beam...  28.502321
# 8   /home/awa/awa_data/12-05_6DReconstruction/beam...  25.767525
# 9   /home/awa/awa_data/12-05_6DReconstruction/beam...  28.954004
# 10  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 11  /home/awa/awa_data/12-05_6DReconstruction/beam...  26.678792
# 12  /home/awa/awa_data/12-05_6DReconstruction/beam...  26.290285
# 13  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 14  /home/awa/awa_data/12-05_6DReconstruction/beam...  26.764852
# 15  /home/awa/awa_data/12-05_6DReconstruction/beam...  19.055362
# 16  /home/awa/awa_data/12-05_6DReconstruction/beam...  24.478707
# 17  /home/awa/awa_data/12-05_6DReconstruction/beam...  19.809232
# 18  /home/awa/awa_data/12-05_6DReconstruction/beam...  22.248095
# 19  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 20  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 21  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 22  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 23  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 24  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 25  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 26  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 27  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 28  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 29  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 30  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 31  /home/awa/awa_data/12-05_6DReconstruction/beam...  16.907591
# 32  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 33  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 34  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 35  /home/awa/awa_data/12-05_6DReconstruction/beam...  23.990972
# 36  /home/awa/awa_data/12-05_6DReconstruction/beam...  20.178197
# 37  /home/awa/awa_data/12-05_6DReconstruction/beam...  28.475526
# 38  /home/awa/awa_data/12-05_6DReconstruction/beam...  34.821751
# 39  /home/awa/awa_data/12-05_6DReconstruction/beam...  21.856195
# 40  /home/awa/awa_data/12-05_6DReconstruction/beam...   27.84309
# 41  /home/awa/awa_data/12-05_6DReconstruction/beam...  37.525312
# 42  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 43  /home/awa/awa_data/12-05_6DReconstruction/beam...  34.009656
# 44  /home/awa/awa_data/12-05_6DReconstruction/beam...  35.780625
# 45  /home/awa/awa_data/12-05_6DReconstruction/beam...  27.596791
# 46  /home/awa/awa_data/12-05_6DReconstruction/beam...  32.064873
# 47  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 48  /home/awa/awa_data/12-05_6DReconstruction/beam...        NaN
# 49  /home/awa/awa_data/12-05_6DReconstruction/beam...  26.044897
#
#     xopt_runtime  xopt_error
# 0      26.565845       False
# 1      26.565845       False
# 2      26.565845       False
# 3      26.565845       False
# 4      26.565845       False
# 5      29.655039       False
# 6      29.655039       False
# 7      29.655039       False
# 8      29.655039       False
# 9      29.655039       False
# 10     24.335089       False
# 11     24.335089       False
# 12     24.335089       False
# 13     24.335089       False
# 14     24.335089       False
# 15     22.325313       False
# 16     22.325313       False
# 17     22.325313       False
# 18     22.325313       False
# 19     22.325313       False
# 20     29.546503       False
# 21     29.546503       False
# 22     29.546503       False
# 23     29.546503       False
# 24     29.546503       False
# 25     34.574100       False
# 26     34.574100       False
# 27     34.574100       False
# 28     34.574100       False
# 29     34.574100       False
# 30     18.210988       False
# 31     18.210988       False
# 32     18.210988       False
# 33     18.210988       False
# 34     18.210988       False
# 35     26.350359       False
# 36     26.350359       False
# 37     26.350359       False
# 38     26.350359       False
# 39     26.350359       False
# 40     29.573958       False
# 41     29.573958       False
# 42     29.573958       False
# 43     29.573958       False
# 44     29.573958       False
# 45     32.468173       False
# 46     32.468173       False
# 47     32.468173       False
# 48     32.468173       False
# 49     32.468173       False

# %%
# visualize result
X.data.plot(x=X.vocs.variable_names[0],y="Cy")
# Out:
# <Axes: xlabel='AWALLRF:K5:SetPhase'>

# %% [markdown]
# ### Polynomial fit for TDC calibration
# do a linear fit of px centroid to TDC amplitude
#
# TDC deflection to screen from zero crossing
# - $ y_f = \kappa L z_0 $
# - $z = \frac{\phi \lambda}{2\pi}$
# - $\kappa = \frac{2\pi}{L\lambda}\frac{\Delta y}{\Delta \phi}$
# - To double check $\kappa = \frac{eV}{pc}\frac{2\pi}{\lambda}$

# %%
import numpy as np
print(
    X.data[TDC_PHASE_PV].to_numpy(dtype="float"), 
    X.data["Cy"].to_numpy(dtype="float")
)
p = np.polyfit(
    X.data[TDC_PHASE_PV].to_numpy(dtype="float"), 
    X.data["Cy"].to_numpy(dtype="float"), 
    1
)
print(p)

slope = p[0]
meters_per_pixel = 1158 / 50e-3  # m / px
rad_per_pv = 180 / 3.14 # rad

slope_m_per_rad = slope * meters_per_pixel / rad_per_pv # m / rad
tdc_to_screen_drift = 1.521 # m
tdc_wavelength = 1.3e9 / 3e8 # m

kappa = (2*np.pi) / (tdc_wavelength * tdc_to_screen_drift) * slope_m_per_rad
print(kappa) # m^-1
# Out:
# [150.         150.         150.         150.         150.
#  151.11111111 151.11111111 151.11111111 151.11111111 151.11111111
#  152.22222222 152.22222222 152.22222222 152.22222222 152.22222222
#  153.33333333 153.33333333 153.33333333 153.33333333 153.33333333
#  154.44444444 154.44444444 154.44444444 154.44444444 154.44444444
#  155.55555556 155.55555556 155.55555556 155.55555556 155.55555556
#  156.66666667 156.66666667 156.66666667 156.66666667 156.66666667
#  157.77777778 157.77777778 157.77777778 157.77777778 157.77777778
#  158.88888889 158.88888889 158.88888889 158.88888889 158.88888889
#  160.         160.         160.         160.         160.        ] [181.82621825 191.28346761 193.45736943 207.60989796 200.05133257
#  234.92249007 256.15712131 236.28848135 227.22255571 239.97416427
#           nan 267.50561671 278.81863254          nan 273.84287762
#  315.21679675 301.63926731 312.81100397 301.29506384          nan
#           nan          nan          nan          nan          nan
#           nan          nan          nan          nan          nan
#           nan 465.23904581          nan          nan          nan
#  483.9344798  476.39247404 483.67916287 494.47912    477.10320742
#  507.50720232 540.0042738           nan 536.75359    515.48729512
#  558.22215519 542.16986798          nan          nan 546.11904589]
#
# Intel MKL ERROR: Parameter 6 was incorrect on entry to DGELSD.
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[18], line 6
#       1 import numpy as np
#       2 print(
#       3     X.data[TDC_PHASE_PV].to_numpy(dtype="float"),
#       4     X.data["Cy"].to_numpy(dtype="float")
#       5 )
# ----> 6 p = np.polyfit(
#       7     X.data[TDC_PHASE_PV].to_numpy(dtype="float"),
#       8     X.data["Cy"].to_numpy(dtype="float"),
#       9     1
#      10 )
#      11 print(p)
#      13 slope = p[0]
#
# File ~/miniconda3/envs/awa-badger/lib/python3.9/site-packages/numpy/lib/polynomial.py:669, in polyfit(x, y, deg, rcond, full, w, cov)
#     667 scale = NX.sqrt((lhs*lhs).sum(axis=0))
#     668 lhs /= scale
# --> 669 c, resids, rank, s = lstsq(lhs, rhs, rcond)
#     670 c = (c.T/scale).T  # broadcast scale coefficients
#     672 # warn on rank reduction, which indicates an ill conditioned matrix
#
# File ~/miniconda3/envs/awa-badger/lib/python3.9/site-packages/numpy/linalg/linalg.py:2326, in lstsq(a, b, rcond)
#    2323 if n_rhs == 0:
#    2324     # lapack can't handle n_rhs = 0 - so allocate the array one larger in that axis
#    2325     b = zeros(b.shape[:-2] + (m, n_rhs + 1), dtype=b.dtype)
# -> 2326 x, resids, rank, s = gufunc(a, b, rcond, signature=signature, extobj=extobj)
#    2327 if m == 0:
#    2328     x[...] = 0
#
# File ~/miniconda3/envs/awa-badger/lib/python3.9/site-packages/numpy/linalg/linalg.py:124, in _raise_linalgerror_lstsq(err, flag)
#     123 def _raise_linalgerror_lstsq(err, flag):
# --> 124     raise LinAlgError("SVD did not converge in Linear Least Squares")
#
# LinAlgError: SVD did not converge in Linear Least Squares
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "awa5:5064"
#     Source File: ../cac.cpp line 1237
#     Current Time: Tue Dec 05 2023 15:31:37.890129338
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.746071899
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.746203969
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.746315711
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.746424132
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.747549659
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.747663102
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.748057198
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.748140512
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:32:10.748221861
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Virtual circuit disconnect"
#     Context: "awa5:5064"
#     Source File: ../cac.cpp line 1237
#     Current Time: Tue Dec 05 2023 15:35:08.214642695
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.734250833
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.734384963
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.734499115
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.734609440
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.735424374
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.735547767
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArrayData", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.735882038
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize0_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.736008597
# ..................................................................
# CA.Client.Exception...............................................
#     Warning: "Identical process variable names on multiple servers"
#     Context: "Channel: "13ARV1:image1:ArraySize1_RBV", Connecting to: 146.139.52.185:5064, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Tue Dec 05 2023 15:36:32.736070911
# ..................................................................

# %%
# calc from approx energy TDC voltage
tdc_voltage = 1
beam_momentum = 48e6
print((tdc_voltage / beam_momentum) * (2*np.pi / tdc_wavelength) )
