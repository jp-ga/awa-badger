# %%
# create function to get data from h5 files
import numpy as np
import h5py
import os

# %%
def read_file(fname):
    with h5py.File(fname) as f:
        #data_x = np.array((
        #    f["images"].attrs["quad_pv_name"],
        #    f["images"].attrs["tdc_name"],
        #    f["images"].attrs["dipole_name"],
        #))
        images = f["images"][:]

    return 0, images

# %%
data_dir = "/home/awa/awa_data/01-16_6DReconstruction/reconstruction_scan/"

# %%
from epics import caget_many
pv_list = ['13ARV1:image1:ArrayData',"13ARV1:image1:ArraySize0_RBV","13ARV1:image1:ArraySize1_RBV"]
img,nx,ny = caget_many(pv_list)
img = img.reshape(ny,nx)

# %matplotlib widget
from circle_detection import ScreenFinder
a = ScreenFinder(img)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a.circle.center
# Out:
# (605.972893459426, 548.297654864609)

# %%
a.circle.radius*2
# Out:
# 920.222068426736

# %%
test_img = read_file(os.path.join(data_dir, "DYG15_test.h5"))
# %matplotlib widget
from circle_detection import ScreenFinder
b = ScreenFinder(test_img[1][0])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 test_img = read_file(os.path.join(data_dir, "DYG15_test.h5"))
#       2 get_ipython().run_line_magic('matplotlib', 'widget')
#       3 from circle_detection import ScreenFinder
#
# Cell In[2], line 2, in read_file(fname)
#       1 def read_file(fname):
# ----> 2     with h5py.File(fname) as f:
#       3         #data_x = np.array((
#       4         #    f["images"].attrs["quad_pv_name"],
#       5         #    f["images"].attrs["tdc_name"],
#       6         #    f["images"].attrs["dipole_name"],
#       7         #))
#       8         images = f["images"][:]
#      10     return 0, images
#
# File ~/miniconda3/envs/awa-badger/lib/python3.9/site-packages/h5py/_hl/files.py:567, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     558     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     559                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     560                      alignment_threshold=alignment_threshold,
#     561                      alignment_interval=alignment_interval,
#     562                      meta_block_size=meta_block_size,
#     563                      **kwds)
#     564     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     565                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     566                      fs_page_size=fs_page_size)
# --> 567     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     569 if isinstance(libver, tuple):
#     570     self._libver = libver
#
# File ~/miniconda3/envs/awa-badger/lib/python3.9/site-packages/h5py/_hl/files.py:231, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     229     if swmr and swmr_support:
#     230         flags |= h5f.ACC_SWMR_READ
# --> 231     fid = h5f.open(name, flags, fapl=fapl)
#     232 elif mode == 'r+':
#     233     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:106, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to open file (unable to open file: name = '/home/awa/awa_data/01-16_6DReconstruction/reconstruction_scan/DYG15_test.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
b.circle.center

# %%
b.circle.radius*2
