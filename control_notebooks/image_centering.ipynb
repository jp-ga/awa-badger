# %%
# create function to get data from h5 files
import numpy as np
import h5py
import os

# %%
def read_file(fname):
    with h5py.File(fname) as f:
        #data_x = np.array((
        #    f["images"].attrs["quad_pv_name"],
        #    f["images"].attrs["tdc_name"],
        #    f["images"].attrs["dipole_name"],
        #))
        images = f["images"][:]

    return 0, images

# %%
data_dir = "/home/awa/awa_data/01-16_6DReconstruction/reconstruction_scan/"

# %%
test_img = np.load(data_dir + "DYG15_background.npy")
# %matplotlib widget
from circle_detection import ScreenFinder
a = ScreenFinder(test_img)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
test_img.shape
# Out:
# (1200, 1920)

# %%
a.circle.center
# Out:
# (1078.816168925593, 590.6854866239997)

# %%
a.circle.radius*2

# %%
test_img = read_file(os.path.join(data_dir, "DYG15_test.h5"))
# %matplotlib widget
from circle_detection import ScreenFinder
b = ScreenFinder(test_img[1][0])

# %%
b.circle.center

# %%
b.circle.radius*2
