# %%
from camera import load_camera

# %%
camera = load_camera("WYG8")
# Out:
# setting camera WYG8
# CA.Client.Exception...............................................
# ...
#     Context: "Channel: "13ARV1:cam1:Acquire", Connecting to: 146.139.52.185:36475, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
#     Current Time: Thu May 09 2024 15:58:05.098971214
# ..................................................................
# "
# CA.Client.Exception...............................................
# ...
#     Context: "Channel: "13ARV1:cam1:Acquire", Connecting to: 146.139.52.185:36475, Ignored: awa5:36475    Source File: ../cac.cpp line 1320
#     Current Time: Thu May 09 2024 15:58:05.099121980
# ..................................................................
# errlog: 1 messages were discarded
# CA.Client.Exception...............................................
# ...
#     Context: "Channel: "13ARV1:cam1:Acquire", Connecting to: 146.139.52.185:36475, Ignored: awa5:5064"
#     Source File: ../cac.cpp line 1320
# ...

# %%
data = camera.get_raw_data()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data = camera.get_raw_data()
#
# File ~/awa-badger/control_notebooks/../plugins/interfaces/diagnostics.py:480, in AWABlackflyDiagnostic.get_raw_data(self)
#     478 results = caget_many(self.pv_names)
#     479 if results[0] is None:
# --> 480     raise RuntimeError(
#     481         "epics returned no image values, make sure blackfly phobeus is active"
#     482     )
#     483 results[0] = np.uint16(results[0])
#     485 e_pvs = copy(self.extra_pvs)
#
# RuntimeError: epics returned no image values, make sure blackfly phobeus is active

# %%
# %matplotlib widget
from circle_detection import ScreenFinder
a = ScreenFinder(data[0])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
a.circle.radius
# Out:
# 173.02994558695784

# %%
a.circle.center
# Out:
# (230.6743282995433, 228.71935159087047)
